# %%
from mmsdk import mmdatasdk
import pickle

# ✅ 特征路径
recipe = {
    "glove_vectors": r"D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\language\CMU_MOSEI_TimestampedWordVectors.csd",
    "COVAREP": r"D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\acoustic\CMU_MOSEI_COVAREP.csd",
    "OpenFace_2": r"D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\visual\CMU_MOSEI_VisualOpenFace2.csd",
    "FACET 4.2": r"D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\visual\CMU_MOSEI_VisualFacet42.csd"
}

# ✅ 标签路径
label_recipe = {
    "All Labels": r"D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\labels\CMU_MOSEI_Labels.csd"
}
label_dir = r"D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\labels"

# ✅ 加载 + 对齐
dataset = mmdatasdk.mmdataset(recipe)
dataset.add_computational_sequences(label_recipe, label_dir)
dataset.align('All Labels')

# ✅ 保存为 segment 级别结构
with open("cmumosei_highlevel.pkl", "wb") as f:
    pickle.dump(dataset, f)

print("✅ 对齐完成并保存为 cmumosei_highlevel.pkl（含 segment）")
# Out:
# [2025-04-09 05:42:37.740] | Success | Computational sequence read from file D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\language\CMU_MOSEI_TimestampedWordVectors.csd ...
# [2025-04-09 05:42:37.789] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2025-04-09 05:42:37.789] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2025-04-09 05:42:38.424] | Success | <glove_vectors> computational sequence data in correct format.
# [2025-04-09 05:42:38.424] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2025-04-09 05:42:38.424] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:42:38.425] | Success | Computational sequence read from file D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\acoustic\CMU_MOSEI_COVAREP.csd ...
# [2025-04-09 05:42:38.490] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2025-04-09 05:42:38.490] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2025-04-09 05:42:39.097] | Success | <COVAREP> computational sequence data in correct format.
# [2025-04-09 05:42:39.097] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2025-04-09 05:42:39.097] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:42:39.099] | Success | Computational sequence read from file D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\visual\CMU_MOSEI_VisualOpenFace2.csd ...
# [2025-04-09 05:42:39.141] | Status  | Checking the integrity of the <OpenFace_2> computational sequence ...
# [2025-04-09 05:42:39.141] | Status  | Checking the format of the data in <OpenFace_2> computational sequence ...
# [2025-04-09 05:42:39.767] | Success | <OpenFace_2> computational sequence data in correct format.
# [2025-04-09 05:42:39.767] | Status  | Checking the format of the metadata in <OpenFace_2> computational sequence ...
# [2025-04-09 05:42:39.767] | Warning | <OpenFace_2> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:42:39.767] | Success | Computational sequence read from file D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\visual\CMU_MOSEI_VisualFacet42.csd ...
# [2025-04-09 05:42:39.813] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2025-04-09 05:42:39.813] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2025-04-09 05:42:40.464] | Success | <FACET 4.2> computational sequence data in correct format.
# [2025-04-09 05:42:40.464] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2025-04-09 05:42:40.464] | Warning | <FACET 4.2> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:42:40.464] | Success | Dataset initialized successfully ...
# [2025-04-09 05:42:40.493] | Success | Computational sequence read from file D:\9444\CMU-MultimodalSDK-main\CMU-MOSEI\labels\CMU_MOSEI_Labels.csd ...
# [2025-04-09 05:42:40.953] | Status  | Checking the integrity of the <All Labels> computational sequence ...
# [2025-04-09 05:42:40.953] | Status  | Checking the format of the data in <All Labels> computational sequence ...
# [2025-04-09 05:42:41.803] | Success | <All Labels> computational sequence data in correct format.
# [2025-04-09 05:42:41.803] | Status  | Checking the format of the metadata in <All Labels> computational sequence ...
# [2025-04-09 05:42:41.803] | Warning | <All Labels> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05
# [2025-04-09 05:48:36.631] | Status  | Pre-alignment done for <FACET 4.2> ...
# [2025-04-09 05:50:30.342] | Status  | Alignment starting ...
# [2025-04-09 05:53:56.257] | Success | Alignment to <All Labels> complete.
# [2025-04-09 05:53:56.259] | Status  | Replacing dataset content with aligned computational sequences
# [2025-04-09 05:54:02.330] | Success | Initialized empty <glove_vectors> computational sequence.
# [2025-04-09 05:54:02.331] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2025-04-09 05:54:02.455] | Success | <glove_vectors> computational sequence data in correct format.
# [2025-04-09 05:54:02.455] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2025-04-09 05:54:02.457] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:54:02.457] | Success | Initialized empty <COVAREP> computational sequence.
# [2025-04-09 05:54:02.457] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2025-04-09 05:54:02.477] | Success | <COVAREP> computational sequence data in correct format.
# [2025-04-09 05:54:02.477] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2025-04-09 05:54:02.477] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:54:02.477] | Success | Initialized empty <OpenFace_2> computational sequence.
# [2025-04-09 05:54:02.477] | Status  | Checking the format of the data in <OpenFace_2> computational sequence ...
# [2025-04-09 05:54:02.500] | Success | <OpenFace_2> computational sequence data in correct format.
# [2025-04-09 05:54:02.500] | Status  | Checking the format of the metadata in <OpenFace_2> computational sequence ...
# [2025-04-09 05:54:02.500] | Warning | <OpenFace_2> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:54:02.500] | Success | Initialized empty <FACET 4.2> computational sequence.
# [2025-04-09 05:54:02.500] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2025-04-09 05:54:02.521] | Success | <FACET 4.2> computational sequence data in correct format.
# [2025-04-09 05:54:02.521] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2025-04-09 05:54:02.521] | Warning | <FACET 4.2> computational sequence does not have all the required metadata ... continuing
# [2025-04-09 05:54:02.521] | Success | Initialized empty <All Labels> computational sequence.
# [2025-04-09 05:54:02.521] | Status  | Checking the format of the data in <All Labels> computational sequence ...
# [2025-04-09 05:54:02.543] | Success | <All Labels> computational sequence data in correct format.
# [2025-04-09 05:54:02.544] | Status  | Checking the format of the metadata in <All Labels> computational sequence ...
# [2025-04-09 05:54:02.544] | Warning | <All Labels> computational sequence does not have all the required metadata ... continuing
# ✅ 数据对齐完成并保存为 cmumosei_highlevel.pkl

# %%
cmumosei_highlevel.computational_sequences
cmumosei_highlevel
#└── computational_sequences   # 字典
#    ├── 'glove_vectors'       # 文本模态
#    │     ├── data            # 里面是每个 video_id -> 特征矩阵 + 时间戳
#   │     └── metadata
#   ├── 'COVAREP'             # 音频模态
#   │     ├── data
#   │     └── metadata
#   ├── 'OpenFace_2'          # 视频模态
#   │     ├── data
#   │     └── metadata
#   ├── ...

# %%
cmumosei_highlevel.computational_sequences['glove_vectors'].metadata
# Out:
# {'alignment compatible': True,
#  'computational sequence description': 'Word vector sequences for CMU-MOSEI Dataset',
#  'computational sequence version': 1.0,
#  'contact': 'abagherz@andrew.cmu.edu',
#  'creator': 'Amir Zadeh',
#  'dataset bib citation': '@inproceedings{cmumoseiacl2018, title={Multimodal Language Analysis in the Wild: {CMU-MOSEI} Dataset and Interpretable Dynamic Fusion Graph}, author={Zadeh, Amir and Liang, Paul Pu and Vanbriesen, Jon and Poria, Soujanya and Cambria, Erik and Chen, Minghai and Morency, Louis-Philippe},booktitle={Association for Computational Linguistics (ACL)},year={2018}}',
#  'dataset name': 'CMU-MOSEI',
#  'dataset version': 1.0,
#  'dimension names': ['vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector',
#   'vector'],
#  'featureset bib citation': '@article{P2FA,title={Speaker identification on the SCOTUS corpus},author={Yuan, Jiahong and Liberman, Mark},journal={Journal of the Acoustical Society of America},volume={123},number={5},pages={3878},year={2008},publisher={[New York: Acoustical Society of America]}}',
#  'md5': None,
#  'root name': 'glove_vectors',
#  'uuid': '8ac9704c-49b3-40ba-8c37-f029d3ddce43'}

# %%
video_id = list(cmumosei_highlevel.computational_sequences['glove_vectors'].data.keys())[0]  # 拿第一个视频
sample = cmumosei_highlevel.computational_sequences['glove_vectors'].data[video_id]

print(f"Video ID: {video_id}")
print(f"Features shape: {sample['features'].shape}")
print(f"Intervals shape: {sample['intervals'].shape}")
print(f"First few intervals: {sample['intervals'][:5]}")
print(f"First few features: {sample['features'][:5]}")
# Out:
# Video ID: --qXJuDtHPw[0]
# Features shape: (22, 300)
# Intervals shape: (22, 2)
# First few intervals: [[23.199      23.47913832]
#  [23.47913832 23.69863946]
#  [23.69863946 23.90816327]
#  [23.90816327 24.11768707]
#  [24.11768707 24.23741497]]
# First few features: [[ 0.16844   0.12176  -0.25024  ... -0.50685  -0.12019  -0.23835 ]
#  [ 0.        0.        0.       ...  0.        0.        0.      ]
#  [ 0.18733   0.40595  -0.51174  ...  0.16495   0.18757   0.53874 ]
#  [ 0.11527   0.014791 -0.41083  ...  0.089616  0.45656   0.17307 ]
#  [ 0.09852   0.25001  -0.27018  ... -0.062639  0.24424   0.17779 ]]

# %%
import torch
from torch.utils.data import Dataset

class CMUMOSEIDataset(Dataset):
    def __init__(self, data, modalities=['glove_vectors', 'COVAREP', 'OpenFace_2'], max_seq_len=50):
        self.data = data
        self.modalities = modalities
        self.max_seq_len = max_seq_len
        
        self.samples = []
        for video_id in list(data['All Labels'].keys()):
            for segment in data['All Labels'][video_id].keys():
                self.samples.append((video_id, segment))
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        video_id, segment = self.samples[idx]
        
        features = []
        for modality in self.modalities:
            feature = self.data[modality][video_id][segment]['features']  # (T, D)
            feature = torch.tensor(feature, dtype=torch.float)
            feature = self._pad_or_truncate(feature)
            features.append(feature)

        # 拼接模态
        multimodal_feature = torch.cat(features, dim=-1)  # (max_seq_len, total_dim)

        # 修复 label 的访问方式
        label = self.data['All Labels'][video_id][segment]['features'][0]  # scalar

        return multimodal_feature, torch.tensor(label, dtype=torch.float)

    def _pad_or_truncate(self, feature):
        T, D = feature.shape
        if T >= self.max_seq_len:
            return feature[:self.max_seq_len]
        else:
            pad = torch.zeros((self.max_seq_len - T, D))
            return torch.cat([feature, pad], dim=0)
dataset = CMUMOSEIDataset(cmumosei_highlevel)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import pickle

with open("cmumosei_highlevel.pkl", "rb") as f:
    cmumosei_highlevel = pickle.load(f)
